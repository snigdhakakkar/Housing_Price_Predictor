# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
housing_data = pd.read_csv('datasets/housing.csv')

housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16060    -122.49     37.76                49.0       1724.0           295.0
# 13670    -117.25     34.07                21.0       3067.0           706.0
# 9746     -121.62     36.63                52.0       1437.0           298.0
# 8943     -118.47     34.01                44.0       2017.0           343.0
# 19578    -120.86     37.69                 5.0       6660.0          1217.0
#
#        population  households  median_income  median_house_value  \
# 16060       795.0       297.0         4.3977            353600.0
# 13670      2140.0       687.0         2.4432             78800.0
# 9746        836.0       257.0         3.6286            165500.0
# 8943        958.0       382.0         6.1014            480100.0
# 19578      3012.0      1087.0         3.0809            143600.0
#
#       ocean_proximity
# 16060        NEAR BAY
# 13670          INLAND
# 9746        <1H OCEAN
# 8943        <1H OCEAN
# 19578          INLAND

# %%
housing_data = housing_data.dropna()

# %%
housing_data.shape
# Out:
# (20433, 10)

# %%
housing_data.loc[housing_data['median_house_value'] == 500001].count()
# Out:
# longitude             958
# latitude              958
# housing_median_age    958
# total_rooms           958
# total_bedrooms        958
# population            958
# households            958
# median_income         958
# median_house_value    958
# ocean_proximity       958
# dtype: int64

# %%
housing_data = housing_data.drop(housing_data.loc[housing_data['median_house_value'] == 500001].index)

# %%
housing_data.shape
# Out:
# (19475, 10)

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
#One-hot encoding
housing_data = pd.get_dummies(housing_data, columns = ['ocean_proximity'])

# %%
housing_data.shape
# Out:
# (19475, 14)

# %%
 housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12473    -121.47     38.58                43.0       3807.0           952.0
# 4821     -118.31     34.05                38.0       1864.0           515.0
# 2490     -120.31     36.65                24.0        943.0           209.0
# 19887    -119.12     36.29                29.0       1638.0           323.0
# 10268    -117.88     33.87                21.0       1519.0           388.0
#
#        population  households  median_income  median_house_value  \
# 12473      1484.0       850.0         2.3266            137500.0
# 4821       1768.0       439.0         1.9336            190600.0
# 2490        514.0       156.0         2.2500             76600.0
# 19887       942.0       322.0         2.1731             66200.0
# 10268      1203.0       366.0         3.2083            145300.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 12473                          0                       1
# 4821                           1                       0
# 2490                           0                       1
# 19887                          0                       1
# 10268                          1                       0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 12473                       0                         0
# 4821                        0                         0
# 2490                        0                         0
# 19887                       0                         0
# 10268                       0                         0
#
#        ocean_proximity_NEAR OCEAN
# 12473                           0
# 4821                            0
# 2490                            0
# 19887                           0
# 10268                           0

# %%
X = housing_data.drop('median_house_value', axis=1)
y = housing_data['median_house_value']

# %%
X.columns
# Out:
# Index([u'longitude', u'latitude', u'housing_median_age', u'total_rooms',
#        u'total_bedrooms', u'population', u'households', u'median_income',
#        u'ocean_proximity_<1H OCEAN', u'ocean_proximity_INLAND',
#        u'ocean_proximity_ISLAND', u'ocean_proximity_NEAR BAY',
#        u'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape, X_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
y_train.shape, y_test.shape
# Out:
# ((15580,), (3895,))

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(normalize=True).fit(X_train, y_train)

# %%
print('Training score:' , linear_model.score(X_train, y_train))
# Out:
# ('Training score:', 0.6140221611045132)

# %%
predictors = X_train.columns

predictors
# Out:
# Index([u'longitude', u'latitude', u'housing_median_age', u'total_rooms',
#        u'total_bedrooms', u'population', u'households', u'median_income',
#        u'ocean_proximity_<1H OCEAN', u'ocean_proximity_INLAND',
#        u'ocean_proximity_ISLAND', u'ocean_proximity_NEAR BAY',
#        u'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
coef = pd.Series(linear_model.coef_, predictors).sort_values()

print(coef)
# Out:
# longitude                    -2.272260e+04
# latitude                     -2.072601e+04
# population                   -2.916892e+01
# total_rooms                  -7.351275e+00
# households                    4.719455e+01
# total_bedrooms                8.536682e+01
# housing_median_age            9.016660e+02
# median_income                 3.855305e+04
# ocean_proximity_INLAND        1.868058e+18
# ocean_proximity_NEAR BAY      1.868058e+18
# ocean_proximity_<1H OCEAN     1.868058e+18
# ocean_proximity_NEAR OCEAN    1.868058e+18
# ocean_proximity_ISLAND        1.868058e+18
# dtype: float64

# %%
linear_model.coef_
# Out:
# array([-2.27225962e+04, -2.07260081e+04,  9.01665953e+02, -7.35127477e+00,
#         8.53668245e+01, -2.91689154e+01,  4.71945490e+01,  3.85530475e+04,
#         1.86805772e+18,  1.86805772e+18,  1.86805772e+18,  1.86805772e+18,
#         1.86805772e+18])

# %%
y_pred = linear_model.predict(X_test)

# %%
df_pred_actual = pd.DataFrame({'predicted': y_pred, 'actual': y_test})

df_pred_actual.head(10)
# Out:
#          actual  predicted
# 8394   177300.0   214272.0
# 7417   153800.0   187648.0
# 17075  218100.0   179712.0
# 2059    65300.0   128768.0
# 16054  336100.0   279296.0
# 8508   242300.0   227840.0
# 1247    75000.0    77824.0
# 15343  189800.0   185600.0
# 13497   67800.0    58112.0
# 14052  142300.0   191744.0

# %%
from sklearn.metrics import r2_score

print('Testing_score: ', r2_score(y_test,y_pred))
# Out:
# ('Testing_score: ', 0.6080267907665415)

# %%
fig, ax = plt.subplots(1,1, figsize = (12,8))

plt.scatter(y_test, y_pred)

plt.show()

# %%
df_pred_actual_sample = df_pred_actual.sample(100)
df_pred_actual_sample = df_pred_actual_sample.reset_index()

# %%
df_pred_actual_sample.head()
# Out:
#    index    actual  predicted
# 0  12575   71800.0   138240.0
# 1  15994  358600.0   272128.0
# 2   3215   51700.0    92928.0
# 3  17565  220600.0   239872.0
# 4  15860  321600.0   280832.0

# %%
plt.figure(figsize = (20,10))

plt.plot(df_pred_actual_sample['predicted'], label=['Predicted'])
plt.plot(df_pred_actual_sample['actual'], label=['Actual'])

plt.ylabel('median_house_value')

plt.legend()
plt.show()
